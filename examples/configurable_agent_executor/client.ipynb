# %% [markdown]
# # Client
#
# Demo of a client interacting with a custom runnable executor that supports configuration.
#
# This server does not support invoke or batch! only stream and astream log! (see backend code.)
#
# The underlying backend code is just a demo in this case -- it's working around an existing bug, but uses
# the opportunity to show how to create custom runnables.

# %% [markdown]
# You can interact with this via API directly

# %%
import requests

inputs = {"input": {"input": "what does Xuyan think of cats?"}}
response = requests.post("http://localhost:8000/stream", json=inputs)

print(response.text)
# Out:
# event: metadata
# data: {"run_id": "cc2a8c9a-0fcc-475c-9ac6-36b7d277f258"}
#
# event: data
# data: {"actions":[{"tool":"get_eugene_thoughts","tool_input":{"query":"cats"},"log":"\nInvoking: `get_eugene_thoughts` with `{'query': 'cats'}`\n\n\n","type":"AgentActionMessageLog","message_log":[{"content":"","additional_kwargs":{"function_call":{"arguments":"{\"query\": \"cats\"}","name":"get_eugene_thoughts"}},"response_metadata":{"finish_reason":"function_call","model_name":"llama3-groq-70b-8192-tool-use-preview","system_fingerprint":"fp_ee4b521143"},"type":"AIMessageChunk","name":null,"id":"run-69bb60c6-5253-4d0c-b14a-d53bbf2d9fa6","example":false,"tool_calls":[],"invalid_tool_calls":[],"usage_metadata":null,"tool_call_chunks":[]}]}],"messages":[{"content":"","additional_kwargs":{"function_call":{"arguments":"{\"query\": \"cats\"}","name":"get_eugene_thoughts"}},"response_metadata":{"finish_reason":"function_call","model_name":"llama3-groq-70b-8192-tool-use-preview","system_fingerprint":"fp_ee4b521143"},"type":"AIMessageChunk","name":null,"id":"run-69bb60c6-5253-4d0c-b14a-d53bbf2d9fa6","example":false,"tool_calls":[],"invalid_tool_calls":[],"usage_metadata":null,"tool_call_chunks":[]}]}
#
# event: data
# data: {"steps":[{"action":{"tool":"get_eugene_thoughts","tool_input":{"query":"cats"},"log":"\nInvoking: `get_eugene_thoughts` with `{'query': 'cats'}`\n\n\n","type":"AgentActionMessageLog","message_log":[{"content":"","additional_kwargs":{"function_call":{"arguments":"{\"query\": \"cats\"}","name":"get_eugene_thoughts"}},"response_metadata":{"finish_reason":"function_call","model_name":"llama3-groq-70b-8192-tool-use-preview","system_fingerprint":"fp_ee4b521143"},"type":"AIMessageChunk","name":null,"id":"run-69bb60c6-5253-4d0c-b14a-d53bbf2d9fa6","example":false,"tool_calls":[],"invalid_tool_calls":[],"usage_metadata":null,"tool_call_chunks":[]}]},"observation":[{"id":null,"metadata":{},"page_content":"猫咪喜欢鱼","type":"Document"},{"id":null,"metadata":{},"page_content":"狗狗喜欢棍子","type":"Document"}]}],"messages":[{"content":"[Document(page_content='猫咪喜欢鱼'), Document(page_content='狗狗喜欢棍子')]","additional_kwargs":{},"response_metadata":{},"type":"function","name":"get_eugene_thoughts","id":null}]}
#
# event: data
# data: {"output":"Xuyan thinks that cats like fish and dogs like sticks.","messages":[{"content":"Xuyan thinks that cats like fish and dogs like sticks.","additional_kwargs":{},"response_metadata":{},"type":"ai","name":null,"id":null,"example":false,"tool_calls":[],"invalid_tool_calls":[],"usage_metadata":null}]}
#
# event: end

# %% [markdown]
# You can also interact with this via the RemoteRunnable interface (to use in other chains)

# %%
from langserve import RemoteRunnable

remote_runnable = RemoteRunnable("http://localhost:8000/")

# %% [markdown]
# Remote runnable has the same interface as local runnables

# %%
async for chunk in remote_runnable.astream({"input": "hi!"}):
    print(chunk)
# Out:
# {'output': 'Hi! How can I assist you today?', 'messages': [AIMessage(content='Hi! How can I assist you today?')]}

# %%
async for chunk in remote_runnable.astream_log({"input": "what does Xuyan think about cats?"}):
    print(chunk)
# Out:
# RunLogPatch({'op': 'replace',
#   'path': '',
#   'value': {'final_output': None,
#             'id': '571616ea-d2f2-4229-9143-0f72cdc467c3',
#             'logs': {},
#             'name': 'executor',
#             'streamed_output': [],
#             'type': 'chain'}})
# RunLogPatch({'op': 'add',
#   'path': '/logs/RunnableSequence',
#   'value': {'end_time': None,
#             'final_output': None,
#             'id': '28a93572-c7d8-4a68-b784-333affd1f1af',
#             'metadata': {'__langserve_endpoint': 'stream_log',
#                          '__langserve_version': '0.2.3',
#                          '__useragent': 'python-httpx/0.27.0',
#                          'llm_temperature': 0.0},
#             'name': 'RunnableSequence',
#             'start_time': '2024-09-05T08:31:14.961+00:00',
#             'streamed_output': [],
#             'streamed_output_str': [],
#             'tags': [],
#             'type': 'chain'}})
# RunLogPatch({'op': 'add',
#   'path': '/logs/RunnableParallel<input,agent_scratchpad>',
#   'value': {'end_time': None,
#             'final_output': None,
#             'id': '29794c4f-ae80-461c-adae-fe899fb8c73c',
#             'metadata': {'__langserve_endpoint': 'stream_log',
#                          '__langserve_version': '0.2.3',
#                          '__useragent': 'python-httpx/0.27.0',
#                          'llm_temperature': 0.0},
#             'name': 'RunnableParallel<input,agent_scratchpad>',
#             'start_time': '2024-09-05T08:31:14.971+00:00',
#             'streamed_output': [],
#             'streamed_output_str': [],
#             'tags': ['seq:step:1'],
#             'type': 'chain'}})
# RunLogPatch({'op': 'add',
#   'path': '/logs/RunnableLambda',
#   'value': {'end_time': None,
#             'final_output': None,
#             'id': 'ab49d8a2-4e11-4766-a2df-aa422c0f53f5',
#             'metadata': {'__langserve_endpoint': 'stream_log',
#                          '__langserve_version': '0.2.3',
#                          '__useragent': 'python-httpx/0.27.0',
#                          'llm_temperature': 0.0},
#             'name': 'RunnableLambda',
#             'start_time': '2024-09-05T08:31:14.973+00:00',
#             'streamed_output': [],
#             'streamed_output_str': [],
#             'tags': ['map:key:input'],
#             'type': 'chain'}})
# RunLogPatch({'op': 'add',
#   'path': '/logs/RunnableLambda:2',
#   'value': {'end_time': None,
#             'final_output': None,
#             'id': '350cc5c9-6416-47ed-b72a-b39f5c37ae09',
#             'metadata': {'__langserve_endpoint': 'stream_log',
#                          '__langserve_version': '0.2.3',
#                          '__useragent': 'python-httpx/0.27.0',
#                          'llm_temperature': 0.0},
#             'name': 'RunnableLambda',
#             'start_time': '2024-09-05T08:31:14.973+00:00',
#             'streamed_output': [],
#             'streamed_output_str': [],
#             'tags': ['map:key:agent_scratchpad'],
#             'type': 'chain'}})
# RunLogPatch({'op': 'add',
#   'path': '/logs/RunnableLambda/streamed_output/-',
#   'value': 'what does Xuyan think about cats?'})
# RunLogPatch({'op': 'add', 'path': '/logs/RunnableLambda:2/streamed_output/-', 'value': []})
# RunLogPatch({'op': 'add',
#   'path': '/logs/RunnableParallel<input,agent_scratchpad>/streamed_output/-',
#   'value': {'input': 'what does Xuyan think about cats?'}})
# RunLogPatch({'op': 'add',
#   'path': '/logs/RunnableParallel<input,agent_scratchpad>/streamed_output/-',
#   'value': {'agent_scratchpad': []}})
# RunLogPatch({'op': 'add',
#   'path': '/logs/RunnableLambda/final_output',
#   'value': {'output': 'what does Xuyan think about cats?'}},
#  {'op': 'add',
#   'path': '/logs/RunnableLambda/end_time',
#   'value': '2024-09-05T08:31:14.976+00:00'})
# RunLogPatch({'op': 'add',
#   'path': '/logs/RunnableLambda:2/final_output',
#   'value': {'output': []}},
#  {'op': 'add',
#   'path': '/logs/RunnableLambda:2/end_time',
#   'value': '2024-09-05T08:31:14.977+00:00'})
# RunLogPatch({'op': 'add',
#   'path': '/logs/RunnableParallel<input,agent_scratchpad>/final_output',
#   'value': {'agent_scratchpad': [],
#             'input': 'what does Xuyan think about cats?'}},
#  {'op': 'add',
#   'path': '/logs/RunnableParallel<input,agent_scratchpad>/end_time',
#   'value': '2024-09-05T08:31:14.978+00:00'})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatPromptTemplate',
#   'value': {'end_time': None,
#             'final_output': None,
#             'id': '37a047d5-dab3-4115-80ed-7db086066c7c',
#             'metadata': {'__langserve_endpoint': 'stream_log',
#                          '__langserve_version': '0.2.3',
#                          '__useragent': 'python-httpx/0.27.0',
#                          'llm_temperature': 0.0},
#             'name': 'ChatPromptTemplate',
#             'start_time': '2024-09-05T08:31:14.980+00:00',
#             'streamed_output': [],
#             'streamed_output_str': [],
#             'tags': ['seq:step:2'],
#             'type': 'prompt'}})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatPromptTemplate/final_output',
#   'value': {'messages': [SystemMessage(content='你是一个有用的助手。'),
#                          HumanMessage(content='what does Xuyan think about cats?')]}},
#  {'op': 'add',
#   'path': '/logs/ChatPromptTemplate/end_time',
#   'value': '2024-09-05T08:31:14.981+00:00'})
# RunLogPatch({'op': 'add',
#   'path': '/logs/LLM',
#   'value': {'end_time': None,
#             'final_output': None,
#             'id': '10d382c4-4829-4e5d-8008-041e43341896',
#             'metadata': {'__langserve_endpoint': 'stream_log',
#                          '__langserve_version': '0.2.3',
#                          '__useragent': 'python-httpx/0.27.0',
#                          'llm_temperature': 0.0,
#                          'ls_model_name': 'llama3-groq-70b-8192-tool-use-preview',
#                          'ls_model_type': 'chat',
#                          'ls_provider': 'openai',
#                          'ls_temperature': 0.0},
#             'name': 'LLM',
#             'start_time': '2024-09-05T08:31:14.985+00:00',
#             'streamed_output': [],
#             'streamed_output_str': [],
#             'tags': ['seq:step:3'],
#             'type': 'llm'}})
# RunLogPatch({'op': 'add', 'path': '/logs/LLM/streamed_output_str/-', 'value': ''},
#  {'op': 'add',
#   'path': '/logs/LLM/streamed_output/-',
#   'value': AIMessageChunk(content='', id='run-10d382c4-4829-4e5d-8008-041e43341896')})
# RunLogPatch({'op': 'add', 'path': '/logs/LLM/streamed_output_str/-', 'value': ''},
#  {'op': 'add',
#   'path': '/logs/LLM/streamed_output/-',
#   'value': AIMessageChunk(content='', additional_kwargs={'function_call': {'arguments': '{"query": "cats"}', 'name': 'get_eugene_thoughts'}}, id='run-10d382c4-4829-4e5d-8008-041e43341896')})
# RunLogPatch({'op': 'add', 'path': '/logs/LLM/streamed_output_str/-', 'value': ''},
#  {'op': 'add',
#   'path': '/logs/LLM/streamed_output/-',
#   'value': AIMessageChunk(content='', response_metadata={'finish_reason': 'function_call', 'model_name': 'llama3-groq-70b-8192-tool-use-preview', 'system_fingerprint': 'fp_ee4b521143'}, id='run-10d382c4-4829-4e5d-8008-041e43341896')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/LLM/final_output',
#   'value': LLMResult(generations=[[ChatGenerationChunk(generation_info={'finish_reason': 'function_call', 'model_name': 'llama3-groq-70b-8192-tool-use-preview', 'system_fingerprint': 'fp_ee4b521143'}, message=AIMessageChunk(content='', additional_kwargs={'function_call': {'arguments': '{"query": "cats"}', 'name': 'get_eugene_thoughts'}}, response_metadata={'finish_reason': 'function_call', 'model_name': 'llama3-groq-70b-8192-tool-use-preview', 'system_fingerprint': 'fp_ee4b521143'}, id='run-10d382c4-4829-4e5d-8008-041e43341896'))]], llm_output=None, run=None)},
#  {'op': 'add',
#   'path': '/logs/LLM/end_time',
#   'value': '2024-09-05T08:31:16.011+00:00'})
# RunLogPatch({'op': 'add',
#   'path': '/logs/OpenAIFunctionsAgentOutputParser',
#   'value': {'end_time': None,
#             'final_output': None,
#             'id': '7d7cf8ed-2ddd-47e3-9960-2208fe979b2f',
#             'metadata': {'__langserve_endpoint': 'stream_log',
#                          '__langserve_version': '0.2.3',
#                          '__useragent': 'python-httpx/0.27.0',
#                          'llm_temperature': 0.0},
#             'name': 'OpenAIFunctionsAgentOutputParser',
#             'start_time': '2024-09-05T08:31:16.012+00:00',
#             'streamed_output': [],
#             'streamed_output_str': [],
#             'tags': ['seq:step:4'],
#             'type': 'parser'}})
# RunLogPatch({'op': 'add',
#   'path': '/logs/OpenAIFunctionsAgentOutputParser/final_output',
#   'value': {'output': AgentActionMessageLog(tool='get_eugene_thoughts', tool_input={'query': 'cats'}, log="\nInvoking: `get_eugene_thoughts` with `{'query': 'cats'}`\n\n\n", message_log=[AIMessageChunk(content='', additional_kwargs={'function_call': {'arguments': '{"query": "cats"}', 'name': 'get_eugene_thoughts'}}, response_metadata={'finish_reason': 'function_call', 'model_name': 'llama3-groq-70b-8192-tool-use-preview', 'system_fingerprint': 'fp_ee4b521143'}, id='run-10d382c4-4829-4e5d-8008-041e43341896')])}},
#  {'op': 'add',
#   'path': '/logs/OpenAIFunctionsAgentOutputParser/end_time',
#   'value': '2024-09-05T08:31:16.013+00:00'})
# RunLogPatch({'op': 'add',
#   'path': '/logs/RunnableSequence/streamed_output/-',
#   'value': AgentActionMessageLog(tool='get_eugene_thoughts', tool_input={'query': 'cats'}, log="\nInvoking: `get_eugene_thoughts` with `{'query': 'cats'}`\n\n\n", message_log=[AIMessageChunk(content='', additional_kwargs={'function_call': {'arguments': '{"query": "cats"}', 'name': 'get_eugene_thoughts'}}, response_metadata={'finish_reason': 'function_call', 'model_name': 'llama3-groq-70b-8192-tool-use-preview', 'system_fingerprint': 'fp_ee4b521143'}, id='run-10d382c4-4829-4e5d-8008-041e43341896')])})
# RunLogPatch({'op': 'add',
#   'path': '/logs/RunnableSequence/final_output',
#   'value': {'output': AgentActionMessageLog(tool='get_eugene_thoughts', tool_input={'query': 'cats'}, log="\nInvoking: `get_eugene_thoughts` with `{'query': 'cats'}`\n\n\n", message_log=[AIMessageChunk(content='', additional_kwargs={'function_call': {'arguments': '{"query": "cats"}', 'name': 'get_eugene_thoughts'}}, response_metadata={'finish_reason': 'function_call', 'model_name': 'llama3-groq-70b-8192-tool-use-preview', 'system_fingerprint': 'fp_ee4b521143'}, id='run-10d382c4-4829-4e5d-8008-041e43341896')])}},
#  {'op': 'add',
#   'path': '/logs/RunnableSequence/end_time',
#   'value': '2024-09-05T08:31:16.014+00:00'})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': {'actions': [AgentActionMessageLog(tool='get_eugene_thoughts', tool_input={'query': 'cats'}, log="\nInvoking: `get_eugene_thoughts` with `{'query': 'cats'}`\n\n\n", message_log=[AIMessageChunk(content='', additional_kwargs={'function_call': {'arguments': '{"query": "cats"}', 'name': 'get_eugene_thoughts'}}, response_metadata={'finish_reason': 'function_call', 'model_name': 'llama3-groq-70b-8192-tool-use-preview', 'system_fingerprint': 'fp_ee4b521143'}, id='run-10d382c4-4829-4e5d-8008-041e43341896')])],
#             'messages': [AIMessageChunk(content='', additional_kwargs={'function_call': {'arguments': '{"query": "cats"}', 'name': 'get_eugene_thoughts'}}, response_metadata={'finish_reason': 'function_call', 'model_name': 'llama3-groq-70b-8192-tool-use-preview', 'system_fingerprint': 'fp_ee4b521143'}, id='run-10d382c4-4829-4e5d-8008-041e43341896')]}},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': {'actions': [AgentActionMessageLog(tool='get_eugene_thoughts', tool_input={'query': 'cats'}, log="\nInvoking: `get_eugene_thoughts` with `{'query': 'cats'}`\n\n\n", message_log=[AIMessageChunk(content='', additional_kwargs={'function_call': {'arguments': '{"query": "cats"}', 'name': 'get_eugene_thoughts'}}, response_metadata={'finish_reason': 'function_call', 'model_name': 'llama3-groq-70b-8192-tool-use-preview', 'system_fingerprint': 'fp_ee4b521143'}, id='run-10d382c4-4829-4e5d-8008-041e43341896')])],
#             'messages': [AIMessageChunk(content='', additional_kwargs={'function_call': {'arguments': '{"query": "cats"}', 'name': 'get_eugene_thoughts'}}, response_metadata={'finish_reason': 'function_call', 'model_name': 'llama3-groq-70b-8192-tool-use-preview', 'system_fingerprint': 'fp_ee4b521143'}, id='run-10d382c4-4829-4e5d-8008-041e43341896')]}})
# RunLogPatch({'op': 'add',
#   'path': '/logs/get_eugene_thoughts',
#   'value': {'end_time': None,
#             'final_output': None,
#             'id': '19286fe5-41e2-4ca5-a3b0-d2bccf3e4930',
#             'metadata': {'__langserve_endpoint': 'stream_log',
#                          '__langserve_version': '0.2.3',
#                          '__useragent': 'python-httpx/0.27.0',
#                          'llm_temperature': 0.0},
#             'name': 'get_eugene_thoughts',
#             'start_time': '2024-09-05T08:31:16.017+00:00',
#             'streamed_output': [],
#             'streamed_output_str': [],
#             'tags': [],
#             'type': 'tool'}})
# RunLogPatch({'op': 'add',
#   'path': '/logs/Retriever',
#   'value': {'end_time': None,
#             'final_output': None,
#             'id': '4e6d8bd9-a75f-4b9e-8e05-358a4990eda7',
#             'metadata': {'__langserve_endpoint': 'stream_log',
#                          '__langserve_version': '0.2.3',
#                          '__useragent': 'python-httpx/0.27.0',
#                          'llm_temperature': 0.0,
#                          'ls_embedding_provider': 'OllamaEmbeddings',
#                          'ls_retriever_name': 'vectorstore',
#                          'ls_vector_store_provider': 'FAISS'},
#             'name': 'Retriever',
#             'start_time': '2024-09-05T08:31:16.018+00:00',
#             'streamed_output': [],
#             'streamed_output_str': [],
#             'tags': ['FAISS', 'OllamaEmbeddings'],
#             'type': 'retriever'}})
# RunLogPatch({'op': 'add',
#   'path': '/logs/Retriever/final_output',
#   'value': {'documents': [Document(page_content='猫咪喜欢鱼'),
#                           Document(page_content='狗狗喜欢棍子')]}},
#  {'op': 'add',
#   'path': '/logs/Retriever/end_time',
#   'value': '2024-09-05T08:31:16.372+00:00'})
# RunLogPatch({'op': 'add',
#   'path': '/logs/get_eugene_thoughts/final_output',
#   'value': {'output': [Document(page_content='猫咪喜欢鱼'),
#                        Document(page_content='狗狗喜欢棍子')]}},
#  {'op': 'add',
#   'path': '/logs/get_eugene_thoughts/end_time',
#   'value': '2024-09-05T08:31:16.373+00:00'})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': {'messages': [FunctionMessage(content="[Document(page_content='猫咪喜欢鱼'), Document(page_content='狗狗喜欢棍子')]", name='get_eugene_thoughts')],
#             'steps': [{'action': AgentActionMessageLog(tool='get_eugene_thoughts', tool_input={'query': 'cats'}, log="\nInvoking: `get_eugene_thoughts` with `{'query': 'cats'}`\n\n\n", message_log=[AIMessageChunk(content='', additional_kwargs={'function_call': {'arguments': '{"query": "cats"}', 'name': 'get_eugene_thoughts'}}, response_metadata={'finish_reason': 'function_call', 'model_name': 'llama3-groq-70b-8192-tool-use-preview', 'system_fingerprint': 'fp_ee4b521143'}, id='run-10d382c4-4829-4e5d-8008-041e43341896')]),
#                        'observation': [Document(page_content='猫咪喜欢鱼'),
#                                        Document(page_content='狗狗喜欢棍子')]}]}},
#  {'op': 'add',
#   'path': '/final_output/steps',
#   'value': [{'action': AgentActionMessageLog(tool='get_eugene_thoughts', tool_input={'query': 'cats'}, log="\nInvoking: `get_eugene_thoughts` with `{'query': 'cats'}`\n\n\n", message_log=[AIMessageChunk(content='', additional_kwargs={'function_call': {'arguments': '{"query": "cats"}', 'name': 'get_eugene_thoughts'}}, response_metadata={'finish_reason': 'function_call', 'model_name': 'llama3-groq-70b-8192-tool-use-preview', 'system_fingerprint': 'fp_ee4b521143'}, id='run-10d382c4-4829-4e5d-8008-041e43341896')]),
#              'observation': [Document(page_content='猫咪喜欢鱼'),
#                              Document(page_content='狗狗喜欢棍子')]}]},
#  {'op': 'add',
#   'path': '/final_output/messages/1',
#   'value': FunctionMessage(content="[Document(page_content='猫咪喜欢鱼'), Document(page_content='狗狗喜欢棍子')]", name='get_eugene_thoughts')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/RunnableSequence:2',
#   'value': {'end_time': None,
#             'final_output': None,
#             'id': 'edb2aa41-1b20-4399-ae18-3c524204375c',
#             'metadata': {'__langserve_endpoint': 'stream_log',
#                          '__langserve_version': '0.2.3',
#                          '__useragent': 'python-httpx/0.27.0',
#                          'llm_temperature': 0.0},
#             'name': 'RunnableSequence',
#             'start_time': '2024-09-05T08:31:16.384+00:00',
#             'streamed_output': [],
#             'streamed_output_str': [],
#             'tags': [],
#             'type': 'chain'}})
# RunLogPatch({'op': 'add',
#   'path': '/logs/RunnableParallel<input,agent_scratchpad>:2',
#   'value': {'end_time': None,
#             'final_output': None,
#             'id': 'b5f5048c-be8c-4479-ac7e-768b3cbf1eef',
#             'metadata': {'__langserve_endpoint': 'stream_log',
#                          '__langserve_version': '0.2.3',
#                          '__useragent': 'python-httpx/0.27.0',
#                          'llm_temperature': 0.0},
#             'name': 'RunnableParallel<input,agent_scratchpad>',
#             'start_time': '2024-09-05T08:31:16.390+00:00',
#             'streamed_output': [],
#             'streamed_output_str': [],
#             'tags': ['seq:step:1'],
#             'type': 'chain'}})
# RunLogPatch({'op': 'add',
#   'path': '/logs/RunnableLambda:3',
#   'value': {'end_time': None,
#             'final_output': None,
#             'id': 'd80c67f5-a913-41cd-8946-0ac147353c34',
#             'metadata': {'__langserve_endpoint': 'stream_log',
#                          '__langserve_version': '0.2.3',
#                          '__useragent': 'python-httpx/0.27.0',
#                          'llm_temperature': 0.0},
#             'name': 'RunnableLambda',
#             'start_time': '2024-09-05T08:31:16.392+00:00',
#             'streamed_output': [],
#             'streamed_output_str': [],
#             'tags': ['map:key:input'],
#             'type': 'chain'}})
# RunLogPatch({'op': 'add',
#   'path': '/logs/RunnableLambda:4',
#   'value': {'end_time': None,
#             'final_output': None,
#             'id': '278f76c5-7220-450f-97af-290b824a80f3',
#             'metadata': {'__langserve_endpoint': 'stream_log',
#                          '__langserve_version': '0.2.3',
#                          '__useragent': 'python-httpx/0.27.0',
#                          'llm_temperature': 0.0},
#             'name': 'RunnableLambda',
#             'start_time': '2024-09-05T08:31:16.392+00:00',
#             'streamed_output': [],
#             'streamed_output_str': [],
#             'tags': ['map:key:agent_scratchpad'],
#             'type': 'chain'}})
# RunLogPatch({'op': 'add',
#   'path': '/logs/RunnableLambda:3/streamed_output/-',
#   'value': 'what does Xuyan think about cats?'})
# RunLogPatch({'op': 'add',
#   'path': '/logs/RunnableLambda:4/streamed_output/-',
#   'value': [AIMessageChunk(content='', additional_kwargs={'function_call': {'arguments': '{"query": "cats"}', 'name': 'get_eugene_thoughts'}}, response_metadata={'finish_reason': 'function_call', 'model_name': 'llama3-groq-70b-8192-tool-use-preview', 'system_fingerprint': 'fp_ee4b521143'}, id='run-10d382c4-4829-4e5d-8008-041e43341896'),
#             FunctionMessage(content="[Document(page_content='猫咪喜欢鱼'), Document(page_content='狗狗喜欢棍子')]", name='get_eugene_thoughts')]})
# RunLogPatch({'op': 'add',
#   'path': '/logs/RunnableParallel<input,agent_scratchpad>:2/streamed_output/-',
#   'value': {'agent_scratchpad': [AIMessageChunk(content='', additional_kwargs={'function_call': {'arguments': '{"query": "cats"}', 'name': 'get_eugene_thoughts'}}, response_metadata={'finish_reason': 'function_call', 'model_name': 'llama3-groq-70b-8192-tool-use-preview', 'system_fingerprint': 'fp_ee4b521143'}, id='run-10d382c4-4829-4e5d-8008-041e43341896'),
#                                  FunctionMessage(content="[Document(page_content='猫咪喜欢鱼'), Document(page_content='狗狗喜欢棍子')]", name='get_eugene_thoughts')]}})
# RunLogPatch({'op': 'add',
#   'path': '/logs/RunnableParallel<input,agent_scratchpad>:2/streamed_output/-',
#   'value': {'input': 'what does Xuyan think about cats?'}})
# RunLogPatch({'op': 'add',
#   'path': '/logs/RunnableLambda:4/final_output',
#   'value': {'output': [AIMessageChunk(content='', additional_kwargs={'function_call': {'arguments': '{"query": "cats"}', 'name': 'get_eugene_thoughts'}}, response_metadata={'finish_reason': 'function_call', 'model_name': 'llama3-groq-70b-8192-tool-use-preview', 'system_fingerprint': 'fp_ee4b521143'}, id='run-10d382c4-4829-4e5d-8008-041e43341896'),
#                        FunctionMessage(content="[Document(page_content='猫咪喜欢鱼'), Document(page_content='狗狗喜欢棍子')]", name='get_eugene_thoughts')]}},
#  {'op': 'add',
#   'path': '/logs/RunnableLambda:4/end_time',
#   'value': '2024-09-05T08:31:16.395+00:00'})
# RunLogPatch({'op': 'add',
#   'path': '/logs/RunnableLambda:3/final_output',
#   'value': {'output': 'what does Xuyan think about cats?'}},
#  {'op': 'add',
#   'path': '/logs/RunnableLambda:3/end_time',
#   'value': '2024-09-05T08:31:16.395+00:00'})
# RunLogPatch({'op': 'add',
#   'path': '/logs/RunnableParallel<input,agent_scratchpad>:2/final_output',
#   'value': {'agent_scratchpad': [AIMessageChunk(content='', additional_kwargs={'function_call': {'arguments': '{"query": "cats"}', 'name': 'get_eugene_thoughts'}}, response_metadata={'finish_reason': 'function_call', 'model_name': 'llama3-groq-70b-8192-tool-use-preview', 'system_fingerprint': 'fp_ee4b521143'}, id='run-10d382c4-4829-4e5d-8008-041e43341896'),
#                                  FunctionMessage(content="[Document(page_content='猫咪喜欢鱼'), Document(page_content='狗狗喜欢棍子')]", name='get_eugene_thoughts')],
#             'input': 'what does Xuyan think about cats?'}},
#  {'op': 'add',
#   'path': '/logs/RunnableParallel<input,agent_scratchpad>:2/end_time',
#   'value': '2024-09-05T08:31:16.396+00:00'})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatPromptTemplate:2',
#   'value': {'end_time': None,
#             'final_output': None,
#             'id': '2963f55f-f652-4af9-9770-2661a5d7e230',
#             'metadata': {'__langserve_endpoint': 'stream_log',
#                          '__langserve_version': '0.2.3',
#                          '__useragent': 'python-httpx/0.27.0',
#                          'llm_temperature': 0.0},
#             'name': 'ChatPromptTemplate',
#             'start_time': '2024-09-05T08:31:16.398+00:00',
#             'streamed_output': [],
#             'streamed_output_str': [],
#             'tags': ['seq:step:2'],
#             'type': 'prompt'}})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatPromptTemplate:2/final_output',
#   'value': {'messages': [SystemMessage(content='你是一个有用的助手。'),
#                          HumanMessage(content='what does Xuyan think about cats?'),
#                          AIMessageChunk(content='', additional_kwargs={'function_call': {'arguments': '{"query": "cats"}', 'name': 'get_eugene_thoughts'}}, response_metadata={'finish_reason': 'function_call', 'model_name': 'llama3-groq-70b-8192-tool-use-preview', 'system_fingerprint': 'fp_ee4b521143'}, id='run-10d382c4-4829-4e5d-8008-041e43341896'),
#                          FunctionMessage(content="[Document(page_content='猫咪喜欢鱼'), Document(page_content='狗狗喜欢棍子')]", name='get_eugene_thoughts')]}},
#  {'op': 'add',
#   'path': '/logs/ChatPromptTemplate:2/end_time',
#   'value': '2024-09-05T08:31:16.399+00:00'})
# RunLogPatch({'op': 'add',
#   'path': '/logs/LLM:2',
#   'value': {'end_time': None,
#             'final_output': None,
#             'id': 'a92459c6-1c91-4036-82cf-66ce1ad114bd',
#             'metadata': {'__langserve_endpoint': 'stream_log',
#                          '__langserve_version': '0.2.3',
#                          '__useragent': 'python-httpx/0.27.0',
#                          'llm_temperature': 0.0,
#                          'ls_model_name': 'llama3-groq-70b-8192-tool-use-preview',
#                          'ls_model_type': 'chat',
#                          'ls_provider': 'openai',
#                          'ls_temperature': 0.0},
#             'name': 'LLM',
#             'start_time': '2024-09-05T08:31:16.401+00:00',
#             'streamed_output': [],
#             'streamed_output_str': [],
#             'tags': ['seq:step:3'],
#             'type': 'llm'}})
# RunLogPatch({'op': 'add', 'path': '/logs/LLM:2/streamed_output_str/-', 'value': ''},
#  {'op': 'add',
#   'path': '/logs/LLM:2/streamed_output/-',
#   'value': AIMessageChunk(content='', id='run-a92459c6-1c91-4036-82cf-66ce1ad114bd')})
# RunLogPatch({'op': 'add', 'path': '/logs/LLM:2/streamed_output_str/-', 'value': 'X'},
#  {'op': 'add',
#   'path': '/logs/LLM:2/streamed_output/-',
#   'value': AIMessageChunk(content='X', id='run-a92459c6-1c91-4036-82cf-66ce1ad114bd')})
# RunLogPatch({'op': 'add', 'path': '/logs/LLM:2/streamed_output_str/-', 'value': 'uy'},
#  {'op': 'add',
#   'path': '/logs/LLM:2/streamed_output/-',
#   'value': AIMessageChunk(content='uy', id='run-a92459c6-1c91-4036-82cf-66ce1ad114bd')})
# RunLogPatch({'op': 'add', 'path': '/logs/LLM:2/streamed_output_str/-', 'value': 'an'},
#  {'op': 'add',
#   'path': '/logs/LLM:2/streamed_output/-',
#   'value': AIMessageChunk(content='an', id='run-a92459c6-1c91-4036-82cf-66ce1ad114bd')})
# RunLogPatch({'op': 'add', 'path': '/logs/LLM:2/streamed_output_str/-', 'value': ' thinks'},
#  {'op': 'add',
#   'path': '/logs/LLM:2/streamed_output/-',
#   'value': AIMessageChunk(content=' thinks', id='run-a92459c6-1c91-4036-82cf-66ce1ad114bd')})
# RunLogPatch({'op': 'add', 'path': '/logs/LLM:2/streamed_output_str/-', 'value': ' that'},
#  {'op': 'add',
#   'path': '/logs/LLM:2/streamed_output/-',
#   'value': AIMessageChunk(content=' that', id='run-a92459c6-1c91-4036-82cf-66ce1ad114bd')})
# RunLogPatch({'op': 'add', 'path': '/logs/LLM:2/streamed_output_str/-', 'value': ' cats'},
#  {'op': 'add',
#   'path': '/logs/LLM:2/streamed_output/-',
#   'value': AIMessageChunk(content=' cats', id='run-a92459c6-1c91-4036-82cf-66ce1ad114bd')})
# RunLogPatch({'op': 'add', 'path': '/logs/LLM:2/streamed_output_str/-', 'value': ' like'},
#  {'op': 'add',
#   'path': '/logs/LLM:2/streamed_output/-',
#   'value': AIMessageChunk(content=' like', id='run-a92459c6-1c91-4036-82cf-66ce1ad114bd')})
# RunLogPatch({'op': 'add', 'path': '/logs/LLM:2/streamed_output_str/-', 'value': ' fish'},
#  {'op': 'add',
#   'path': '/logs/LLM:2/streamed_output/-',
#   'value': AIMessageChunk(content=' fish', id='run-a92459c6-1c91-4036-82cf-66ce1ad114bd')})
# RunLogPatch({'op': 'add', 'path': '/logs/LLM:2/streamed_output_str/-', 'value': ' and'},
#  {'op': 'add',
#   'path': '/logs/LLM:2/streamed_output/-',
#   'value': AIMessageChunk(content=' and', id='run-a92459c6-1c91-4036-82cf-66ce1ad114bd')})
# RunLogPatch({'op': 'add', 'path': '/logs/LLM:2/streamed_output_str/-', 'value': ' dogs'},
#  {'op': 'add',
#   'path': '/logs/LLM:2/streamed_output/-',
#   'value': AIMessageChunk(content=' dogs', id='run-a92459c6-1c91-4036-82cf-66ce1ad114bd')})
# RunLogPatch({'op': 'add', 'path': '/logs/LLM:2/streamed_output_str/-', 'value': ' like'},
#  {'op': 'add',
#   'path': '/logs/LLM:2/streamed_output/-',
#   'value': AIMessageChunk(content=' like', id='run-a92459c6-1c91-4036-82cf-66ce1ad114bd')})
# RunLogPatch({'op': 'add', 'path': '/logs/LLM:2/streamed_output_str/-', 'value': ' sticks'},
#  {'op': 'add',
#   'path': '/logs/LLM:2/streamed_output/-',
#   'value': AIMessageChunk(content=' sticks', id='run-a92459c6-1c91-4036-82cf-66ce1ad114bd')})
# RunLogPatch({'op': 'add', 'path': '/logs/LLM:2/streamed_output_str/-', 'value': '.'},
#  {'op': 'add',
#   'path': '/logs/LLM:2/streamed_output/-',
#   'value': AIMessageChunk(content='.', id='run-a92459c6-1c91-4036-82cf-66ce1ad114bd')})
# RunLogPatch({'op': 'add', 'path': '/logs/LLM:2/streamed_output_str/-', 'value': ''},
#  {'op': 'add',
#   'path': '/logs/LLM:2/streamed_output/-',
#   'value': AIMessageChunk(content='', response_metadata={'finish_reason': 'stop', 'model_name': 'llama3-groq-70b-8192-tool-use-preview', 'system_fingerprint': 'fp_ee4b521143'}, id='run-a92459c6-1c91-4036-82cf-66ce1ad114bd')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/LLM:2/final_output',
#   'value': LLMResult(generations=[[ChatGenerationChunk(text='Xuyan thinks that cats like fish and dogs like sticks.', generation_info={'finish_reason': 'stop', 'model_name': 'llama3-groq-70b-8192-tool-use-preview', 'system_fingerprint': 'fp_ee4b521143'}, message=AIMessageChunk(content='Xuyan thinks that cats like fish and dogs like sticks.', response_metadata={'finish_reason': 'stop', 'model_name': 'llama3-groq-70b-8192-tool-use-preview', 'system_fingerprint': 'fp_ee4b521143'}, id='run-a92459c6-1c91-4036-82cf-66ce1ad114bd'))]], llm_output=None, run=None)},
#  {'op': 'add',
#   'path': '/logs/LLM:2/end_time',
#   'value': '2024-09-05T08:31:16.818+00:00'})
# RunLogPatch({'op': 'add',
#   'path': '/logs/OpenAIFunctionsAgentOutputParser:2',
#   'value': {'end_time': None,
#             'final_output': None,
#             'id': '17c2c4a5-58b4-4119-9e90-c485992018c4',
#             'metadata': {'__langserve_endpoint': 'stream_log',
#                          '__langserve_version': '0.2.3',
#                          '__useragent': 'python-httpx/0.27.0',
#                          'llm_temperature': 0.0},
#             'name': 'OpenAIFunctionsAgentOutputParser',
#             'start_time': '2024-09-05T08:31:16.819+00:00',
#             'streamed_output': [],
#             'streamed_output_str': [],
#             'tags': ['seq:step:4'],
#             'type': 'parser'}})
# RunLogPatch({'op': 'add',
#   'path': '/logs/OpenAIFunctionsAgentOutputParser:2/final_output',
#   'value': {'output': AgentFinish(return_values={'output': 'Xuyan thinks that cats like fish and dogs like sticks.'}, log='Xuyan thinks that cats like fish and dogs like sticks.')}},
#  {'op': 'add',
#   'path': '/logs/OpenAIFunctionsAgentOutputParser:2/end_time',
#   'value': '2024-09-05T08:31:16.820+00:00'})
# RunLogPatch({'op': 'add',
#   'path': '/logs/RunnableSequence:2/streamed_output/-',
#   'value': AgentFinish(return_values={'output': 'Xuyan thinks that cats like fish and dogs like sticks.'}, log='Xuyan thinks that cats like fish and dogs like sticks.')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/RunnableSequence:2/final_output',
#   'value': {'output': AgentFinish(return_values={'output': 'Xuyan thinks that cats like fish and dogs like sticks.'}, log='Xuyan thinks that cats like fish and dogs like sticks.')}},
#  {'op': 'add',
#   'path': '/logs/RunnableSequence:2/end_time',
#   'value': '2024-09-05T08:31:16.821+00:00'})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': {'messages': [AIMessage(content='Xuyan thinks that cats like fish and dogs like sticks.')],
#             'output': 'Xuyan thinks that cats like fish and dogs like '
#                       'sticks.'}},
#  {'op': 'add',
#   'path': '/final_output/output',
#   'value': 'Xuyan thinks that cats like fish and dogs like sticks.'},
#  {'op': 'add',
#   'path': '/final_output/messages/2',
#   'value': AIMessage(content='Xuyan thinks that cats like fish and dogs like sticks.')})

# %%
async for chunk in remote_runnable.astream_log({"input": "what does Xuyan think about cats?"}, include_names=["LLM"]):
    print(chunk)
# Out:
# RunLogPatch({'op': 'replace',
#   'path': '',
#   'value': {'final_output': None,
#             'id': '44e6d5dc-c61f-4350-a43e-c334c686958f',
#             'logs': {},
#             'name': 'executor',
#             'streamed_output': [],
#             'type': 'chain'}})
# RunLogPatch({'op': 'add',
#   'path': '/logs/LLM',
#   'value': {'end_time': None,
#             'final_output': None,
#             'id': '92c0d365-c7fe-4a74-a4cb-74f93e114e0b',
#             'metadata': {'__langserve_endpoint': 'stream_log',
#                          '__langserve_version': '0.2.3',
#                          '__useragent': 'python-httpx/0.27.0',
#                          'llm_temperature': 0.0,
#                          'ls_model_name': 'llama3-groq-70b-8192-tool-use-preview',
#                          'ls_model_type': 'chat',
#                          'ls_provider': 'openai',
#                          'ls_temperature': 0.0},
#             'name': 'LLM',
#             'start_time': '2024-09-05T08:31:21.716+00:00',
#             'streamed_output': [],
#             'streamed_output_str': [],
#             'tags': ['seq:step:3'],
#             'type': 'llm'}})
# RunLogPatch({'op': 'add', 'path': '/logs/LLM/streamed_output_str/-', 'value': ''},
#  {'op': 'add',
#   'path': '/logs/LLM/streamed_output/-',
#   'value': AIMessageChunk(content='', id='run-92c0d365-c7fe-4a74-a4cb-74f93e114e0b')})
# RunLogPatch({'op': 'add', 'path': '/logs/LLM/streamed_output_str/-', 'value': ''},
#  {'op': 'add',
#   'path': '/logs/LLM/streamed_output/-',
#   'value': AIMessageChunk(content='', additional_kwargs={'function_call': {'arguments': '{"query": "cats"}', 'name': 'get_eugene_thoughts'}}, id='run-92c0d365-c7fe-4a74-a4cb-74f93e114e0b')})
# RunLogPatch({'op': 'add', 'path': '/logs/LLM/streamed_output_str/-', 'value': ''},
#  {'op': 'add',
#   'path': '/logs/LLM/streamed_output/-',
#   'value': AIMessageChunk(content='', response_metadata={'finish_reason': 'function_call', 'model_name': 'llama3-groq-70b-8192-tool-use-preview', 'system_fingerprint': 'fp_ee4b521143'}, id='run-92c0d365-c7fe-4a74-a4cb-74f93e114e0b')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/LLM/final_output',
#   'value': LLMResult(generations=[[ChatGenerationChunk(generation_info={'finish_reason': 'function_call', 'model_name': 'llama3-groq-70b-8192-tool-use-preview', 'system_fingerprint': 'fp_ee4b521143'}, message=AIMessageChunk(content='', additional_kwargs={'function_call': {'arguments': '{"query": "cats"}', 'name': 'get_eugene_thoughts'}}, response_metadata={'finish_reason': 'function_call', 'model_name': 'llama3-groq-70b-8192-tool-use-preview', 'system_fingerprint': 'fp_ee4b521143'}, id='run-92c0d365-c7fe-4a74-a4cb-74f93e114e0b'))]], llm_output=None, run=None)},
#  {'op': 'add',
#   'path': '/logs/LLM/end_time',
#   'value': '2024-09-05T08:31:22.182+00:00'})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': {'actions': [AgentActionMessageLog(tool='get_eugene_thoughts', tool_input={'query': 'cats'}, log="\nInvoking: `get_eugene_thoughts` with `{'query': 'cats'}`\n\n\n", message_log=[AIMessageChunk(content='', additional_kwargs={'function_call': {'arguments': '{"query": "cats"}', 'name': 'get_eugene_thoughts'}}, response_metadata={'finish_reason': 'function_call', 'model_name': 'llama3-groq-70b-8192-tool-use-preview', 'system_fingerprint': 'fp_ee4b521143'}, id='run-92c0d365-c7fe-4a74-a4cb-74f93e114e0b')])],
#             'messages': [AIMessageChunk(content='', additional_kwargs={'function_call': {'arguments': '{"query": "cats"}', 'name': 'get_eugene_thoughts'}}, response_metadata={'finish_reason': 'function_call', 'model_name': 'llama3-groq-70b-8192-tool-use-preview', 'system_fingerprint': 'fp_ee4b521143'}, id='run-92c0d365-c7fe-4a74-a4cb-74f93e114e0b')]}},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': {'actions': [AgentActionMessageLog(tool='get_eugene_thoughts', tool_input={'query': 'cats'}, log="\nInvoking: `get_eugene_thoughts` with `{'query': 'cats'}`\n\n\n", message_log=[AIMessageChunk(content='', additional_kwargs={'function_call': {'arguments': '{"query": "cats"}', 'name': 'get_eugene_thoughts'}}, response_metadata={'finish_reason': 'function_call', 'model_name': 'llama3-groq-70b-8192-tool-use-preview', 'system_fingerprint': 'fp_ee4b521143'}, id='run-92c0d365-c7fe-4a74-a4cb-74f93e114e0b')])],
#             'messages': [AIMessageChunk(content='', additional_kwargs={'function_call': {'arguments': '{"query": "cats"}', 'name': 'get_eugene_thoughts'}}, response_metadata={'finish_reason': 'function_call', 'model_name': 'llama3-groq-70b-8192-tool-use-preview', 'system_fingerprint': 'fp_ee4b521143'}, id='run-92c0d365-c7fe-4a74-a4cb-74f93e114e0b')]}})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': {'messages': [FunctionMessage(content="[Document(page_content='猫咪喜欢鱼'), Document(page_content='狗狗喜欢棍子')]", name='get_eugene_thoughts')],
#             'steps': [{'action': AgentActionMessageLog(tool='get_eugene_thoughts', tool_input={'query': 'cats'}, log="\nInvoking: `get_eugene_thoughts` with `{'query': 'cats'}`\n\n\n", message_log=[AIMessageChunk(content='', additional_kwargs={'function_call': {'arguments': '{"query": "cats"}', 'name': 'get_eugene_thoughts'}}, response_metadata={'finish_reason': 'function_call', 'model_name': 'llama3-groq-70b-8192-tool-use-preview', 'system_fingerprint': 'fp_ee4b521143'}, id='run-92c0d365-c7fe-4a74-a4cb-74f93e114e0b')]),
#                        'observation': [Document(page_content='猫咪喜欢鱼'),
#                                        Document(page_content='狗狗喜欢棍子')]}]}},
#  {'op': 'add',
#   'path': '/final_output/steps',
#   'value': [{'action': AgentActionMessageLog(tool='get_eugene_thoughts', tool_input={'query': 'cats'}, log="\nInvoking: `get_eugene_thoughts` with `{'query': 'cats'}`\n\n\n", message_log=[AIMessageChunk(content='', additional_kwargs={'function_call': {'arguments': '{"query": "cats"}', 'name': 'get_eugene_thoughts'}}, response_metadata={'finish_reason': 'function_call', 'model_name': 'llama3-groq-70b-8192-tool-use-preview', 'system_fingerprint': 'fp_ee4b521143'}, id='run-92c0d365-c7fe-4a74-a4cb-74f93e114e0b')]),
#              'observation': [Document(page_content='猫咪喜欢鱼'),
#                              Document(page_content='狗狗喜欢棍子')]}]},
#  {'op': 'add',
#   'path': '/final_output/messages/1',
#   'value': FunctionMessage(content="[Document(page_content='猫咪喜欢鱼'), Document(page_content='狗狗喜欢棍子')]", name='get_eugene_thoughts')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/LLM:2',
#   'value': {'end_time': None,
#             'final_output': None,
#             'id': '7ca3fc91-ed63-4878-b63f-e5833f0fe6bf',
#             'metadata': {'__langserve_endpoint': 'stream_log',
#                          '__langserve_version': '0.2.3',
#                          '__useragent': 'python-httpx/0.27.0',
#                          'llm_temperature': 0.0,
#                          'ls_model_name': 'llama3-groq-70b-8192-tool-use-preview',
#                          'ls_model_type': 'chat',
#                          'ls_provider': 'openai',
#                          'ls_temperature': 0.0},
#             'name': 'LLM',
#             'start_time': '2024-09-05T08:31:22.565+00:00',
#             'streamed_output': [],
#             'streamed_output_str': [],
#             'tags': ['seq:step:3'],
#             'type': 'llm'}})
# RunLogPatch({'op': 'add', 'path': '/logs/LLM:2/streamed_output_str/-', 'value': ''},
#  {'op': 'add',
#   'path': '/logs/LLM:2/streamed_output/-',
#   'value': AIMessageChunk(content='', id='run-7ca3fc91-ed63-4878-b63f-e5833f0fe6bf')})
# RunLogPatch({'op': 'add', 'path': '/logs/LLM:2/streamed_output_str/-', 'value': 'X'},
#  {'op': 'add',
#   'path': '/logs/LLM:2/streamed_output/-',
#   'value': AIMessageChunk(content='X', id='run-7ca3fc91-ed63-4878-b63f-e5833f0fe6bf')})
# RunLogPatch({'op': 'add', 'path': '/logs/LLM:2/streamed_output_str/-', 'value': 'uy'},
#  {'op': 'add',
#   'path': '/logs/LLM:2/streamed_output/-',
#   'value': AIMessageChunk(content='uy', id='run-7ca3fc91-ed63-4878-b63f-e5833f0fe6bf')})
# RunLogPatch({'op': 'add', 'path': '/logs/LLM:2/streamed_output_str/-', 'value': 'an'},
#  {'op': 'add',
#   'path': '/logs/LLM:2/streamed_output/-',
#   'value': AIMessageChunk(content='an', id='run-7ca3fc91-ed63-4878-b63f-e5833f0fe6bf')})
# RunLogPatch({'op': 'add', 'path': '/logs/LLM:2/streamed_output_str/-', 'value': ' thinks'},
#  {'op': 'add',
#   'path': '/logs/LLM:2/streamed_output/-',
#   'value': AIMessageChunk(content=' thinks', id='run-7ca3fc91-ed63-4878-b63f-e5833f0fe6bf')})
# RunLogPatch({'op': 'add', 'path': '/logs/LLM:2/streamed_output_str/-', 'value': ' that'},
#  {'op': 'add',
#   'path': '/logs/LLM:2/streamed_output/-',
#   'value': AIMessageChunk(content=' that', id='run-7ca3fc91-ed63-4878-b63f-e5833f0fe6bf')})
# RunLogPatch({'op': 'add', 'path': '/logs/LLM:2/streamed_output_str/-', 'value': ' cats'},
#  {'op': 'add',
#   'path': '/logs/LLM:2/streamed_output/-',
#   'value': AIMessageChunk(content=' cats', id='run-7ca3fc91-ed63-4878-b63f-e5833f0fe6bf')})
# RunLogPatch({'op': 'add', 'path': '/logs/LLM:2/streamed_output_str/-', 'value': ' like'},
#  {'op': 'add',
#   'path': '/logs/LLM:2/streamed_output/-',
#   'value': AIMessageChunk(content=' like', id='run-7ca3fc91-ed63-4878-b63f-e5833f0fe6bf')})
# RunLogPatch({'op': 'add', 'path': '/logs/LLM:2/streamed_output_str/-', 'value': ' fish'},
#  {'op': 'add',
#   'path': '/logs/LLM:2/streamed_output/-',
#   'value': AIMessageChunk(content=' fish', id='run-7ca3fc91-ed63-4878-b63f-e5833f0fe6bf')})
# RunLogPatch({'op': 'add', 'path': '/logs/LLM:2/streamed_output_str/-', 'value': ' and'},
#  {'op': 'add',
#   'path': '/logs/LLM:2/streamed_output/-',
#   'value': AIMessageChunk(content=' and', id='run-7ca3fc91-ed63-4878-b63f-e5833f0fe6bf')})
# RunLogPatch({'op': 'add', 'path': '/logs/LLM:2/streamed_output_str/-', 'value': ' dogs'},
#  {'op': 'add',
#   'path': '/logs/LLM:2/streamed_output/-',
#   'value': AIMessageChunk(content=' dogs', id='run-7ca3fc91-ed63-4878-b63f-e5833f0fe6bf')})
# RunLogPatch({'op': 'add', 'path': '/logs/LLM:2/streamed_output_str/-', 'value': ' like'},
#  {'op': 'add',
#   'path': '/logs/LLM:2/streamed_output/-',
#   'value': AIMessageChunk(content=' like', id='run-7ca3fc91-ed63-4878-b63f-e5833f0fe6bf')})
# RunLogPatch({'op': 'add', 'path': '/logs/LLM:2/streamed_output_str/-', 'value': ' sticks'},
#  {'op': 'add',
#   'path': '/logs/LLM:2/streamed_output/-',
#   'value': AIMessageChunk(content=' sticks', id='run-7ca3fc91-ed63-4878-b63f-e5833f0fe6bf')})
# RunLogPatch({'op': 'add', 'path': '/logs/LLM:2/streamed_output_str/-', 'value': '.'},
#  {'op': 'add',
#   'path': '/logs/LLM:2/streamed_output/-',
#   'value': AIMessageChunk(content='.', id='run-7ca3fc91-ed63-4878-b63f-e5833f0fe6bf')})
# RunLogPatch({'op': 'add', 'path': '/logs/LLM:2/streamed_output_str/-', 'value': ''},
#  {'op': 'add',
#   'path': '/logs/LLM:2/streamed_output/-',
#   'value': AIMessageChunk(content='', response_metadata={'finish_reason': 'stop', 'model_name': 'llama3-groq-70b-8192-tool-use-preview', 'system_fingerprint': 'fp_ee4b521143'}, id='run-7ca3fc91-ed63-4878-b63f-e5833f0fe6bf')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/LLM:2/final_output',
#   'value': LLMResult(generations=[[ChatGenerationChunk(text='Xuyan thinks that cats like fish and dogs like sticks.', generation_info={'finish_reason': 'stop', 'model_name': 'llama3-groq-70b-8192-tool-use-preview', 'system_fingerprint': 'fp_ee4b521143'}, message=AIMessageChunk(content='Xuyan thinks that cats like fish and dogs like sticks.', response_metadata={'finish_reason': 'stop', 'model_name': 'llama3-groq-70b-8192-tool-use-preview', 'system_fingerprint': 'fp_ee4b521143'}, id='run-7ca3fc91-ed63-4878-b63f-e5833f0fe6bf'))]], llm_output=None, run=None)},
#  {'op': 'add',
#   'path': '/logs/LLM:2/end_time',
#   'value': '2024-09-05T08:31:22.989+00:00'})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': {'messages': [AIMessage(content='Xuyan thinks that cats like fish and dogs like sticks.')],
#             'output': 'Xuyan thinks that cats like fish and dogs like '
#                       'sticks.'}},
#  {'op': 'add',
#   'path': '/final_output/output',
#   'value': 'Xuyan thinks that cats like fish and dogs like sticks.'},
#  {'op': 'add',
#   'path': '/final_output/messages/2',
#   'value': AIMessage(content='Xuyan thinks that cats like fish and dogs like sticks.')})
